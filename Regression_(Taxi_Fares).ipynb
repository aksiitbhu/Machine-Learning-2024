# %% [markdown]
# <a href="https://colab.research.google.com/github/aksiitbhu/Machine-Learning-2024/blob/main/Regression_(Taxi_Fares).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regression with neural networks
#
# Imagine that you work for a taxi company, and that one of your customers' biggest complaints is that they don't know how much a ride will cost until it's over. That's because distance is just one of several factors from which taxi fares are calculated. You decide to do something about it by building a mobile app that customers can use when they climb into a taxi to estimate what the fare will be. To provide the smarts for the app, you intend to use the massive amounts of fare data the company has collected over the years to train a neural network. Let's use a portion of a larger taxi-fare dataset from New York City to train the network to predict a fare amount given the time of day, the pickup and dropoff locations, and other information.
#
# ![](Images/nyc.jpg)

# %% [markdown]
# ## Load and prepare data
#
# Start by loading the dataset and shaping it so that it's suitable for use in machine learning. This dataset is a subset of a much larger dataset containing more than 100 million rows. Recently, the larger dataset was used in Kaggle's [New York City Taxi Fare Prediction](https://www.kaggle.com/c/new-york-city-taxi-fare-prediction) competition. The data requires a fair amount of prep work before it's of any use at all — something that is not uncommon in machine learning. Data scientists often find that collecting and preparing data accounts for 90% or more of their time.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

df = pd.read_csv('taxi-fares.csv')
df.head()
# Out:
#                              key  fare_amount          pickup_datetime  \
# 0  2014-06-15 17:11:00.000000107          7.0  2014-06-15 17:11:00 UTC
# 1   2011-03-14 22:43:00.00000095          4.9  2011-03-14 22:43:00 UTC
# 2   2011-02-14 15:14:00.00000067          6.1  2011-02-14 15:14:00 UTC
# 3   2009-10-29 11:29:00.00000040          6.9  2009-10-29 11:29:00 UTC
# 4   2011-07-02 10:38:00.00000028         10.5  2011-07-02 10:38:00 UTC
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.995420        40.759662         -73.987607         40.751247
# 1        -73.993552        40.731110         -73.998497         40.737200
# 2        -73.972380        40.749527         -73.990638         40.745328
# 3        -73.973703        40.763542         -73.984253         40.758603
# 4        -73.921262        40.743615         -73.967383         40.765162
#
#    passenger_count
# 0                1
# 1                5
# 2                1
# 3                5
# 4                1

# %% [markdown]
# How many rows and columns does the dataset contain?

# %%
df.shape
# Out:
# (55368, 8)

# %% [markdown]
# Are any of the columns missing values?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55368 entries, 0 to 55367
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   key                55368 non-null  object
#  1   fare_amount        55368 non-null  float64
#  2   pickup_datetime    55368 non-null  object
#  3   pickup_longitude   55368 non-null  float64
#  4   pickup_latitude    55368 non-null  float64
#  5   dropoff_longitude  55368 non-null  float64
#  6   dropoff_latitude   55368 non-null  float64
#  7   passenger_count    55368 non-null  int64
# dtypes: float64(5), int64(1), object(2)
# memory usage: 3.4+ MB

# %% [markdown]
# Draw a histogram showing how many rows contain a passenger count of 1, how many contain a passenger count of 2, and so on.

# %%
sns.countplot(x=df['passenger_count'])
# Out:
# <Axes: xlabel='passenger_count', ylabel='count'>

# %% [markdown]
# Most of the rows in the dataset have a passenger count of 1. Remove all rows with multiple passengers and remove the "key" column from the dataset.

# %%
df = df[df['passenger_count'] == 1]
df = df.drop(['key', 'passenger_count'], axis=1)
df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.0  2014-06-15 17:11:00 UTC        -73.995420        40.759662
# 2          6.1  2011-02-14 15:14:00 UTC        -73.972380        40.749527
# 4         10.5  2011-07-02 10:38:00 UTC        -73.921262        40.743615
# 5         15.3  2011-12-09 20:03:00 UTC        -73.973500        40.792610
# 8          7.7  2011-04-02 01:05:15 UTC        -73.979564        40.735405
#
#    dropoff_longitude  dropoff_latitude
# 0         -73.987607         40.751247
# 2         -73.990638         40.745328
# 4         -73.967383         40.765162
# 5         -73.936035         40.856548
# 8         -73.955686         40.768065

# %% [markdown]
# How many rows and columns are left in the dataset?

# %%
df.shape
# Out:
# (38233, 6)

# %% [markdown]
# Find out how much influence input variables such as `latitude` and `longitude` have on the values in the "fare_amount" column.

# %%
df1=df[['fare_amount', 'pickup_longitude','pickup_latitude']]
corr_matrix = df1.corr()
corr_matrix
# Out:
#                   fare_amount  pickup_longitude  pickup_latitude
# fare_amount          1.000000          0.015742        -0.015915
# pickup_longitude     0.015742          1.000000        -0.974220
# pickup_latitude     -0.015915         -0.974220         1.000000

# %% [markdown]
# The numbers don't look very encouraging. Latitudes and longitudes have little to do with fare amounts, at least in their present form. And yet intuitively, they should have a *lot* do with fare amounts since they specify starting and ending points and longer rides incur higher fares.
#
# Now comes the fun part: creating whole new columns of data that have more impact on the outcome — columns whose values are computed from values in other columns. Add columns specifying the day of the week (0=Monday, 1=Sunday, and so on), the hour of the day that the passenger was picked up (0-23), and the distance (through the air, not on the street) in miles that the ride covered. To compute distances, this code assumes that most rides are short and that it is therefore safe to ignore the curvature of the earth.

# %%
corr_matrix['fare_amount'].sort_values(ascending=False)
# Out:
# fare_amount         1.000000
# pickup_longitude    0.015742
# pickup_latitude    -0.015915
# Name: fare_amount, dtype: float64

# %%
import datetime
from math import sqrt


for i, row in df.iterrows():
    dt = datetime.datetime.strptime(row['pickup_datetime'], '%Y-%m-%d %H:%M:%S UTC')
    df.at[i, 'day_of_week'] = dt.weekday()
    df.at[i, 'pickup_time'] = dt.hour
    x = (row['dropoff_longitude'] - row['pickup_longitude']) * 54.6 # 1 degree == 54.6 miles
    y = (row['dropoff_latitude'] - row['pickup_latitude']) * 69.0   # 1 degree == 69 miles
    distance = sqrt(x**2 + y**2)
    df.at[i, 'distance'] = distance

df.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.0  2014-06-15 17:11:00 UTC        -73.995420        40.759662
# 2          6.1  2011-02-14 15:14:00 UTC        -73.972380        40.749527
# 4         10.5  2011-07-02 10:38:00 UTC        -73.921262        40.743615
# 5         15.3  2011-12-09 20:03:00 UTC        -73.973500        40.792610
# 8          7.7  2011-04-02 01:05:15 UTC        -73.979564        40.735405
#
#    dropoff_longitude  dropoff_latitude  day_of_week  pickup_time  distance
# 0         -73.987607         40.751247          6.0         17.0  0.720497
# 2         -73.990638         40.745328          0.0         15.0  1.038136
# 4         -73.967383         40.765162          5.0         10.0  2.924341
# 5         -73.936035         40.856548          4.0         20.0  4.862893
# 8         -73.955686         40.768065          5.0          1.0  2.603493

# %% [markdown]
# Remove columns that are no longer needed.

# %%
df.drop(columns=['pickup_datetime', 'pickup_longitude', 'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude'], inplace=True)
df.head()
# Out:
#    fare_amount  day_of_week  pickup_time  distance
# 0          7.0          6.0         17.0  0.720497
# 2          6.1          0.0         15.0  1.038136
# 4         10.5          5.0         10.0  2.924341
# 5         15.3          4.0         20.0  4.862893
# 8          7.7          5.0          1.0  2.603493

# %% [markdown]
# Run a correlation again.

# %%
corr_matrix = df.corr()
corr_matrix["fare_amount"].sort_values(ascending=False)
# Out:
# fare_amount    1.000000
# distance       0.045873
# day_of_week    0.009196
# pickup_time   -0.019722
# Name: fare_amount, dtype: float64

# %% [markdown]
# There still isn't a strong correlation between distance traveled and fare amount. Perhaps this will provide some clue as to why:

# %%
df.describe()
# Out:
#         fare_amount   day_of_week   pickup_time      distance
# count  38233.000000  38233.000000  38233.000000  38233.000000
# mean      11.214115      2.951534     13.387989     12.018397
# std        9.703149      1.932809      6.446519    217.357022
# min      -22.100000      0.000000      0.000000      0.000000
# 25%        6.000000      1.000000      9.000000      0.762116
# 50%        8.500000      3.000000     14.000000      1.331326
# 75%       12.500000      5.000000     19.000000      2.402226
# max      256.000000      6.000000     23.000000   4923.837280

# %% [markdown]
# The dataset contains outliers, and outliers frequently skew the results of machine-learning models (or prevent them from working at all). Filter the dataset by eliminating negative fare amounts and placing reasonable limits on fares and distance.

# %%
df = df[(df['distance'] > 1.0) & (df['distance'] < 10.0)]
df = df[(df['fare_amount'] > 0.0) & (df['fare_amount'] < 50.0)]
df.shape
# Out:
# (23298, 4)

# %% [markdown]
# Run a correlation again.

# %%
corr_matrix = df.corr()
corr_matrix["fare_amount"].sort_values(ascending=False)
# Out:
# fare_amount    1.000000
# distance       0.851913
# day_of_week   -0.003570
# pickup_time   -0.023085
# Name: fare_amount, dtype: float64

# %% [markdown]
# That looks better! The correlation between the day of the week, the hour of the day, and fare amount is still weak, but let's leave those columns in there since it makes sense that it might take longer to get from point A to point B during rush hour, or that traffic at 5:00 p.m. Friday might be different than traffic at 5:00 p.m. on Saturday.

# %% [markdown]
# # Train a neural network
#
# Now it's time build a neural network and train it with the data prepared in the previous exercise. We'll create two hidden layers with 512 neurons each and an input layer that accepts three values: distance, the day of the week, and the time of day. Since the model is designed to predict a fare amount, the output layer will have one neuron.

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(512, activation='relu', input_dim=3))
model.add(Dense(512, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mae', metrics=['mae'])
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 512)                 │           2,048 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         262,656 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │             513 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 265,217 (1.01 MB)
#  Trainable params: 265,217 (1.01 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Extract the feature columns and the label column and train the model.

# %%
x = df.drop('fare_amount', axis=1)
y = df['fare_amount']

hist = model.fit(x, y, validation_split=0.2, epochs=100, batch_size=100)
# Out:
# Epoch 1/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 3.8449 - mae: 3.8449 - val_loss: 2.3904 - val_mae: 2.3904
# Epoch 2/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 2.3849 - mae: 2.3849 - val_loss: 2.4372 - val_mae: 2.4372
# Epoch 3/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3944 - mae: 2.3944 - val_loss: 2.4741 - val_mae: 2.4741
# Epoch 4/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.4086 - mae: 2.4086 - val_loss: 2.3550 - val_mae: 2.3550
# Epoch 5/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3622 - mae: 2.3622 - val_loss: 2.3592 - val_mae: 2.3592
# Epoch 6/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3271 - mae: 2.3271 - val_loss: 2.3384 - val_mae: 2.3384
# Epoch 7/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3561 - mae: 2.3561 - val_loss: 2.3494 - val_mae: 2.3494
# Epoch 8/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 2.3579 - mae: 2.3579 - val_loss: 2.3477 - val_mae: 2.3477
# Epoch 9/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3535 - mae: 2.3535 - val_loss: 2.3361 - val_mae: 2.3361
# Epoch 10/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3737 - mae: 2.3737 - val_loss: 2.3623 - val_mae: 2.3623
# Epoch 11/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3368 - mae: 2.3368 - val_loss: 2.3848 - val_mae: 2.3848
# Epoch 12/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3194 - mae: 2.3194 - val_loss: 2.3394 - val_mae: 2.3394
# Epoch 13/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2982 - mae: 2.2982 - val_loss: 2.3315 - val_mae: 2.3315
# Epoch 14/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 2.3672 - mae: 2.3672 - val_loss: 2.3215 - val_mae: 2.3215
# Epoch 15/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3331 - mae: 2.3331 - val_loss: 2.4039 - val_mae: 2.4039
# Epoch 16/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2.3166 - mae: 2.3166 - val_loss: 2.3813 - val_mae: 2.3813
# Epoch 17/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3607 - mae: 2.3607 - val_loss: 2.3175 - val_mae: 2.3175
# Epoch 18/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3350 - mae: 2.3350 - val_loss: 2.3689 - val_mae: 2.3689
# Epoch 19/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3766 - mae: 2.3766 - val_loss: 2.4107 - val_mae: 2.4107
# Epoch 20/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 2.3159 - mae: 2.3159 - val_loss: 2.3109 - val_mae: 2.3109
# Epoch 21/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.3492 - mae: 2.3492 - val_loss: 2.3468 - val_mae: 2.3468
# Epoch 22/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3409 - mae: 2.3409 - val_loss: 2.3547 - val_mae: 2.3547
# Epoch 23/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3673 - mae: 2.3673 - val_loss: 2.3242 - val_mae: 2.3242
# Epoch 24/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3264 - mae: 2.3264 - val_loss: 2.5960 - val_mae: 2.5960
# Epoch 25/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3839 - mae: 2.3839 - val_loss: 2.3946 - val_mae: 2.3946
# Epoch 26/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3370 - mae: 2.3370 - val_loss: 2.3956 - val_mae: 2.3956
# Epoch 27/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - loss: 2.3134 - mae: 2.3134 - val_loss: 2.3032 - val_mae: 2.3032
# Epoch 28/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - loss: 2.3266 - mae: 2.3266 - val_loss: 2.3082 - val_mae: 2.3082
# Epoch 29/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.2990 - mae: 2.2990 - val_loss: 2.3515 - val_mae: 2.3515
# Epoch 30/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3326 - mae: 2.3326 - val_loss: 2.3719 - val_mae: 2.3719
# Epoch 31/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3201 - mae: 2.3201 - val_loss: 2.3055 - val_mae: 2.3055
# Epoch 32/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 2.3163 - mae: 2.3163 - val_loss: 2.3094 - val_mae: 2.3094
# Epoch 33/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.3054 - mae: 2.3054 - val_loss: 2.2995 - val_mae: 2.2995
# Epoch 34/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3062 - mae: 2.3062 - val_loss: 2.3227 - val_mae: 2.3227
# Epoch 35/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2604 - mae: 2.2604 - val_loss: 2.2971 - val_mae: 2.2971
# Epoch 36/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 2.3283 - mae: 2.3283 - val_loss: 2.3253 - val_mae: 2.3253
# Epoch 37/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.3099 - mae: 2.3099 - val_loss: 2.3124 - val_mae: 2.3124
# Epoch 38/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2750 - mae: 2.2750 - val_loss: 2.3113 - val_mae: 2.3113
# Epoch 39/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3092 - mae: 2.3092 - val_loss: 2.2852 - val_mae: 2.2852
# Epoch 40/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3087 - mae: 2.3087 - val_loss: 2.3065 - val_mae: 2.3065
# Epoch 41/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3095 - mae: 2.3095 - val_loss: 2.3039 - val_mae: 2.3039
# Epoch 42/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3033 - mae: 2.3033 - val_loss: 2.3130 - val_mae: 2.3130
# Epoch 43/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 2.2754 - mae: 2.2754 - val_loss: 2.2743 - val_mae: 2.2743
# Epoch 44/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3241 - mae: 2.3241 - val_loss: 2.2702 - val_mae: 2.2702
# Epoch 45/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3246 - mae: 2.3246 - val_loss: 2.2988 - val_mae: 2.2988
# Epoch 46/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3005 - mae: 2.3005 - val_loss: 2.3173 - val_mae: 2.3173
# Epoch 47/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3478 - mae: 2.3478 - val_loss: 2.3133 - val_mae: 2.3133
# Epoch 48/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2923 - mae: 2.2923 - val_loss: 2.3112 - val_mae: 2.3112
# Epoch 49/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.2844 - mae: 2.2844 - val_loss: 2.2856 - val_mae: 2.2856
# Epoch 50/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 2.3039 - mae: 2.3039 - val_loss: 2.2695 - val_mae: 2.2695
# Epoch 51/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2967 - mae: 2.2967 - val_loss: 2.2964 - val_mae: 2.2964
# Epoch 52/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2861 - mae: 2.2861 - val_loss: 2.2891 - val_mae: 2.2891
# Epoch 53/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2700 - mae: 2.2700 - val_loss: 2.2760 - val_mae: 2.2760
# Epoch 54/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2786 - mae: 2.2786 - val_loss: 2.2781 - val_mae: 2.2781
# Epoch 55/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2753 - mae: 2.2753 - val_loss: 2.2645 - val_mae: 2.2645
# Epoch 56/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 2.2780 - mae: 2.2780 - val_loss: 2.3698 - val_mae: 2.3698
# Epoch 57/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.3368 - mae: 2.3368 - val_loss: 2.3078 - val_mae: 2.3078
# Epoch 58/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.3256 - mae: 2.3256 - val_loss: 2.3080 - val_mae: 2.3080
# Epoch 59/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2747 - mae: 2.2747 - val_loss: 2.2633 - val_mae: 2.2633
# Epoch 60/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2559 - mae: 2.2559 - val_loss: 2.2707 - val_mae: 2.2707
# Epoch 61/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3018 - mae: 2.3018 - val_loss: 2.2543 - val_mae: 2.2543
# Epoch 62/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - loss: 2.3125 - mae: 2.3125 - val_loss: 2.2762 - val_mae: 2.2762
# Epoch 63/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.2527 - mae: 2.2527 - val_loss: 2.2789 - val_mae: 2.2789
# Epoch 64/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3091 - mae: 2.3091 - val_loss: 2.2820 - val_mae: 2.2820
# Epoch 65/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2440 - mae: 2.2440 - val_loss: 2.2695 - val_mae: 2.2695
# Epoch 66/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3193 - mae: 2.3193 - val_loss: 2.2848 - val_mae: 2.2848
# Epoch 67/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2969 - mae: 2.2969 - val_loss: 2.2946 - val_mae: 2.2946
# Epoch 68/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 2.2665 - mae: 2.2665 - val_loss: 2.2762 - val_mae: 2.2762
# Epoch 69/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2739 - mae: 2.2739 - val_loss: 2.2796 - val_mae: 2.2796
# Epoch 70/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2915 - mae: 2.2915 - val_loss: 2.3082 - val_mae: 2.3082
# Epoch 71/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2740 - mae: 2.2740 - val_loss: 2.2677 - val_mae: 2.2677
# Epoch 72/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2522 - mae: 2.2522 - val_loss: 2.3006 - val_mae: 2.3006
# Epoch 73/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - loss: 2.2566 - mae: 2.2566 - val_loss: 2.3253 - val_mae: 2.3253
# Epoch 74/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - loss: 2.3228 - mae: 2.3228 - val_loss: 2.3026 - val_mae: 2.3026
# Epoch 75/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.3047 - mae: 2.3047 - val_loss: 2.2679 - val_mae: 2.2679
# Epoch 76/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2793 - mae: 2.2793 - val_loss: 2.2533 - val_mae: 2.2533
# Epoch 77/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.3042 - mae: 2.3042 - val_loss: 2.2709 - val_mae: 2.2709
# Epoch 78/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2986 - mae: 2.2986 - val_loss: 2.2600 - val_mae: 2.2600
# Epoch 79/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - loss: 2.2868 - mae: 2.2868 - val_loss: 2.2629 - val_mae: 2.2629
# Epoch 80/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.2739 - mae: 2.2739 - val_loss: 2.3274 - val_mae: 2.3274
# Epoch 81/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2628 - mae: 2.2628 - val_loss: 2.2602 - val_mae: 2.2602
# Epoch 82/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2769 - mae: 2.2769 - val_loss: 2.2671 - val_mae: 2.2671
# Epoch 83/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 2.2884 - mae: 2.2884 - val_loss: 2.2531 - val_mae: 2.2531
# Epoch 84/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2935 - mae: 2.2935 - val_loss: 2.2722 - val_mae: 2.2722
# Epoch 85/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 2.2828 - mae: 2.2828 - val_loss: 2.2581 - val_mae: 2.2581
# Epoch 86/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - loss: 2.2790 - mae: 2.2790 - val_loss: 2.2697 - val_mae: 2.2697
# Epoch 87/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 2.2778 - mae: 2.2778 - val_loss: 2.2619 - val_mae: 2.2619
# Epoch 88/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2911 - mae: 2.2911 - val_loss: 2.3013 - val_mae: 2.3013
# Epoch 89/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.2657 - mae: 2.2657 - val_loss: 2.3113 - val_mae: 2.3113
# Epoch 90/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 2.2569 - mae: 2.2569 - val_loss: 2.2734 - val_mae: 2.2734
# Epoch 91/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 2.2593 - mae: 2.2593 - val_loss: 2.2641 - val_mae: 2.2641
# Epoch 92/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.2921 - mae: 2.2921 - val_loss: 2.2640 - val_mae: 2.2640
# Epoch 93/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2997 - mae: 2.2997 - val_loss: 2.2595 - val_mae: 2.2595
# Epoch 94/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 2.3022 - mae: 2.3022 - val_loss: 2.2750 - val_mae: 2.2750
# Epoch 95/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2854 - mae: 2.2854 - val_loss: 2.2832 - val_mae: 2.2832
# Epoch 96/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 2.2651 - mae: 2.2651 - val_loss: 2.2859 - val_mae: 2.2859
# Epoch 97/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - loss: 2.2672 - mae: 2.2672 - val_loss: 2.2563 - val_mae: 2.2563
# Epoch 98/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 2.2324 - mae: 2.2324 - val_loss: 2.2698 - val_mae: 2.2698
# Epoch 99/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2678 - mae: 2.2678 - val_loss: 2.2907 - val_mae: 2.2907
# Epoch 100/100
# 187/187 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2.2739 - mae: 2.2739 - val_loss: 2.2724 - val_mae: 2.2724

# %% [markdown]
# Plot the training accuracy and validation accuracy over time.

# %%
err = hist.history['mae']
val_err = hist.history['val_mae']
epochs = range(1, len(err) + 1)

plt.plot(epochs, err, '-', label='Training MAE')
plt.plot(epochs, val_err, ':', label='Validation MAE')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Mean Absolute Error')
plt.legend(loc='upper right')
plt.plot()
# Out:
# []

# %% [markdown]
# Get the coefficient of determination (R2) to determine how accurate the model is.

# %%
from sklearn.metrics import r2_score

r2_score(y, model.predict(x))
# Out:
# 729/729 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# 0.7420851217331095

# %% [markdown]
# ## Use the model to predict fare amounts
#
# Finish up by using the trained model to make a pair of predictions. First, estimate what it will cost to hire a taxi for a 2-mile trip at 5:00 p.m. on Friday afternoon.

# %%
import numpy as np

model.predict(np.array([[4, 17, 2.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# array([[10.59762]], dtype=float32)

# %% [markdown]
# Now predict the fare amount for a 2-mile trip taken at 5:00 p.m. one day later (on Saturday).

# %%
model.predict(np.array([[5, 17, 2.0]]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# array([[10.341894]], dtype=float32)

# %% [markdown]
# Does the model predict a higher or lower fare amount for the same trip on Saturday afternoon? Does this make sense given that the data comes from a New York City cab company?
