# %% [markdown]
# <a href="https://colab.research.google.com/github/aksiitbhu/Machine-Learning-2024/blob/main/LinearRegressionLab1GEU2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Error function for 1 degree polynomial with zero intercept
# Equation of the line is ​y = mx + c
# 1. Slope of the line is 1 i.e m = 1.
# 2. Intercept is 0 i.e. c = 0.

# %%
import numpy as np
import matplotlib.pyplot as plt
m = 1
x = np.linspace(1,10,11)
y = m*x
plt.title('Graph of equation y = x')
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
w1 = np.linspace(-6,9,20)
error = 0
it = len(x)
for i in range(it):
  error += (w1*x[i]- y[i])**2
plt.plot(w1,error)
plt.xlabel('W')
plt.ylabel('Error')
plt.title('W vs Error')
plt.scatter(w1,error,c='red')
plt.show()

# %%
m = 1
x = np.linspace(1,10,11)
y = m*x
plt.scatter(x,y,c='blue')
plt.plot(x,y,'red')
plt.title('Graph of equation y = x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
